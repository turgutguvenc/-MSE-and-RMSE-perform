# %%
import pandas as pd

ad = pd.read_csv("../input/advertising1/Advertising.csv")
# ad = pd.read_csv("Advertising.csv", usecols = [1,2,3,4])
# burda indexi kolon olarak aldığı için alttaki şekilde veya bu şekilde çözülebilir
df = ad.copy()
df.head()

# %%
df = df.iloc[:,1:len(df)] # We prevented from taking indexes as column
df.head()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.formula.api as smf

# %%
lm = smf.ols("sales ~ TV", df)
model = lm.fit()

# %% [markdown]
# The mean squared error(MSE) tells you how close a regression line is to a set of points. It does this by taking the distances from the points to the regression line (these distances are the “errors”) and squaring them;

# %%
mse = mean_squared_error(y, model.fittedvalues)

# %%
mse

# %%
import numpy as np
rmse = np.sqrt(mse) # square root mse

# %%
rmse

# %%
#Comparing Table
k_t = pd.DataFrame({"real_y": y[0:10],
                  "pred_y": reg.predict(X)[0:10]})

# %%
k_t

# %%
# error after estimation against each variable y
k_t["error"] = k_t["real_y"] - k_t["pred_y"]

# %%
k_t

# %%
k_t["error_square"] = k_t["error"]**2 
# we square the variables so that they do not cancel each other.

# %%
k_t

# %%
np.sum(k_t["error_square"]) # total error

# %%
np.mean(k_t["error_square"]) # mean squared error

# %%
np.sqrt(np.mean(k_t["error_square"])) # root mean squared error
# we calculated manually

# %%
plt.plot(model.resid)

# %%
model.resid[0:10] # this show as otomatically he residuals

# %%
import matplotlib.pyplot as plt
plt.plot(model.resid)
# we should examine out of -+6 and must undertand that why are they go out the normal
